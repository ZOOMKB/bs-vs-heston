# %% [markdown]
# # Setup and Data Acquisition
#
# The implementation lives in `src/market_data.py`. This notebook runs the two-stage pipeline and displays the resulting datasets.

# %%
from pathlib import Path
import sys

from IPython.display import display

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebook":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.market_data import ENRICHED_OPTIONS_PATH, RAW_OPTIONS_PATH, print_summary, run_data_acquisition

# %%
raw_df, options_df = run_data_acquisition(ticker_symbol="SPY")

print(f"Raw dataset saved to: {RAW_OPTIONS_PATH}")
print(f"Final dataset saved to: {ENRICHED_OPTIONS_PATH}")
print_summary(options_df)
# Out:
# Raw dataset saved to: /Users/mykolanocap/Development/citi-project/data/spy_options_raw.csv
# Final dataset saved to: /Users/mykolanocap/Development/citi-project/data/spy_options_enriched.csv
# Options Data
# Ticker: SPY
# Total options: 7722
# Calls: 4047
# Puts: 3675
# Expirations: 24
# Strike range: $50 - $1360
# T range: 0.0192 - 2.6274 years
#
# Per-expiry breakdown:
# Expiry         Calls  Puts  Total   T (years)        r
# 2026-05-08       182   184    366      0.0192   3.710%
# 2026-05-15       220   206    426      0.0384   3.710%
# 2026-05-22       165   185    350      0.0575   3.710%
# 2026-05-29       221   202    423      0.0767   3.710%
# 2026-06-05       106   148    254      0.0959   3.711%
# 2026-06-18       152   129    281      0.1315   3.709%
# 2026-06-30       238   261    499      0.1644   3.701%
# 2026-07-17       110    85    195      0.2110   3.680%
# 2026-07-31       185   166    351      0.2493   3.680%
# ...

# %%
display(raw_df.head())
display(options_df.head())
# Out:
#   ticker      expiry option_type  strike  lastPrice     bid     ask  volume  \
# 0    SPY  2026-05-08        call   435.0     280.52  284.26  287.05     1.0
# 1    SPY  2026-05-08        call   480.0     230.77  239.29  242.08     1.0
# 2    SPY  2026-05-08        call   485.0     175.75  234.30  237.09     NaN
# 3    SPY  2026-05-08        call   490.0     170.80  229.30  232.09     NaN
# 4    SPY  2026-05-08        call   495.0     155.77  224.30  227.10     NaN
#
#    openInterest  impliedVolatility  ...           S   spot_date  \
# 0           1.0           1.125004  ...  720.650024  2026-05-01
# 1           2.0           1.066411  ...  720.650024  2026-05-01
# 2           3.0           1.066411  ...  720.650024  2026-05-01
# 3           3.0           1.039067  ...  720.650024  2026-05-01
# 4           4.0           1.023442  ...  720.650024  2026-05-01
#
#            downloaded_at_utc      contractSymbol             lastTradeDate  \
# ...
